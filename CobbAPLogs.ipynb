# %% [markdown]
# # Sandbox

# %%
import pandas
import numpy as np
from LogPlotUtil import LogPlotUtil
fileName = "datalog1.csv"
logPath = f"C:\\Users\\Nick\\OneDrive\\Documents\\ApLogs\\{fileName}"
fl = pandas.read_csv( logPath , encoding = 'unicode_escape' )

# %%
import matplotlib.pyplot as plt
print("Wastegete Duty" in fl.columns)
print(fl.columns)
# tst = np.float32(fl['KS Noise Cyl 1 (raw)'])
# print(len(tst) , np.max(tst))
# start = 0
# end = len(tst)
# plt.plot(tst[start:end])
# Out:
# False
# Index(['Time (sec)', 'AC Compressor Sw (on/off)', 'AF Correction 1 (%)',
#        'AF Correction 3 (%)', 'AF Learning 1 (%)', 'AF Learning 3 (%)',
#        'AF Sens 1 Ratio (AFR)', 'AVCS Exh Left (°)', 'AVCS In Left (°)',
#        'Accel Position (%)', 'Baro Pressure (psi)', 'Battery Volts (V)',
#        'Boost (psi)', 'CL Fuel Target (AFR)', 'Calculated Load (g/rev)',
#        'Comm Fuel Final (AFR)', 'Coolant Temp (F)', 'Dyn Adv Mult (DAM)',
#        'EGR Commanded (steps)', 'Feedback Knock (°)', 'Fine Knock Learn (°)',
#        'Fuel Cut (cylinders)', 'Gear Position (gear)', 'Ign Comp IAT (°)',
#        'Ignition Timing (°)', 'Inj Duty Cycle (%)', 'Inj PW (ms)',
#        'Intake Temp (F)', 'Intake Temp Manifold (F)', 'MAF Freq (kHz)',
#        'Man Abs Press (psi)', 'Oil Temp (F)', 'RPM (RPM)', 'Req Torque (Nm)',
#        'Req Torque Bst Targets (Nm)', 'TD Boost Error (psi)',
#        'TD Integ WG Pos Corr (mm)', 'TD Prop WG Pos Corr (mm)',
# ...

# %% [markdown]
# # Util Instance

# %%
from LogPlotUtil import LogPlotUtil

logname = "datalog1.csv"
logPath = f"C:\\Users\\Nick\\OneDrive\\Documents\\ApLogs\\{logname}"

utilInst = LogPlotUtil(logPath , 7.5) # Path , Autofind Throttle Threshold
utilInst.plotLog(  0.1     ,   0.9    ,    1) 
#               Start_Prct , End_Prct , High Throttle Event Autofind (overrides first two, finds all events)
# Out:
#      ----------------------------------------------------------------- HIGH THROTTLE EVENT 1 -----------------------------------------------------------------
# 'MAF Corr Final (g/s)' not found in CSV
# 'MAF Volts (V)' not found in CSV
# 'Fuel Pressure (psi)' not found in CSV
# 'Fuel Pressure Target (psi)' not found in CSV
# KS Noise Cyl 1-4 not being logged. Skipping plot...
# AVCS not being logged. Skipping plot...
#      ----------------------------------------------------------------- HIGH THROTTLE EVENT 2 -----------------------------------------------------------------
# 'MAF Corr Final (g/s)' not found in CSV
# 'MAF Volts (V)' not found in CSV
# 'Fuel Pressure (psi)' not found in CSV
# 'Fuel Pressure Target (psi)' not found in CSV
# KS Noise Cyl 1-4 not being logged. Skipping plot...
# AVCS not being logged. Skipping plot...
